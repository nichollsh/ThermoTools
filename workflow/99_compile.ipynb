# %% [markdown]
# # Bring it all together
# Creates a single NetCDF (.nc) file for each gas species

# %%
from thermotools.plot import *

import netCDF4 as nc
import time, glob, os
import numpy as np


from thermotools import moles, phase
from thermotools import get_gendir, empty_dir
from thermotools.util import makezip, writesum

today = int(time.strftime("%Y%m%d"))
print(today)
print(type(today))
# Out:
# Querying Woitke+2017 phase change data for Al2O3
# Querying Woitke+2017 phase change data for Al2O3
#     multiple entries for Al2O3, found: Al2O3[s] and Al2O3[l]
#     using Al2O3[s] data for Al2O3
# Querying Woitke+2017 phase change data for Al2O3
# Querying Woitke+2017 phase change data for Al2O3
#     multiple entries for Al2O3, found: Al2O3[s] and Al2O3[l]
#     using Al2O3[s] data for Al2O3
# Querying Woitke+2017 phase change data for MgAl2O4
# Querying Woitke+2017 phase change data for MgAl2O4
#     multiple entries for MgAl2O4, found: MgAl2O4[s] and MgAl2O4[l]
#     using MgAl2O4[s] data for MgAl2O4
# Querying Woitke+2017 phase change data for MgAl2O4
# Querying Woitke+2017 phase change data for MgAl2O4
#     multiple entries for MgAl2O4, found: MgAl2O4[s] and MgAl2O4[l]
#     using MgAl2O4[s] data for MgAl2O4
# Querying Woitke+2017 phase change data for TiO2
# Querying Woitke+2017 phase change data for TiO2
#     multiple entries for TiO2, found: TiO2[s] and TiO2[l]
# ...

# %%
datdir = os.path.join(get_gendir(), "compiled", "dat")
empty_dir(datdir)

pltdir = os.path.join(get_gendir(), "compiled", "plt")
empty_dir(pltdir)

# %%
# collect gases
gases = []

# AGNI defaults
gases.extend([
    # (semi)refractory atoms
    "Na", "Si", "Ti", "V", "Mg", "K", "Fe", "Li", "Ca", "Al", "Cr",
    # ions
    # "H-",
    # rock vapours
    "SiO2", "SiO", "SiH", "SiH2", "SiH4",
    "FeO", "FeH",
    "Mg2", "MgO",
    "TiO", "TiO2", "VO", "CrH",
    "CaO", "AlO", "Na2", "NaO", "NaOH", "KOH",
    "HAlO2"
    "H", "O", "C", "N", "S", "P", 
    # Noble gases
    "He", "Ne", "Ar", "Kr", "Xe",
    # basic
    "CH4", "CO2", "CO", "H2", "H2O", "O2", "OH", "O3",
    # carbon
    "H2O2", "C2H6", "C2H4","C2H2",  "CH3", "H2CO", "HO2", "C2", "C3", "C4", "C5",
    "CH3CHO", "CH3OOH", "CH3COCH3", "CH3COCHO", "CHOCHO",
    "C2H5CHO", "HOCH2CHO", "C2H5COCH3", "CH3ONO2", "C2H3", "C3H4", "C4H3",
    "C2N2", "HCO",
    # sulfur
    "SO", "S2", "S3", "S6", "S8", "SO2", "SO3", "H2SO4", "H2S", "CS2", "OCS",
    "CH3SH", "CH3S", "C2H6S", "C2H6S2",
    # nitrogen
    "N2", "HCN", "NH3",  "HNO3", "N2O5", "HONO", "HO2NO2",
    "NO3", "N2O", "NO", "NO2", "N2O4", "N2H4", "N2O3", "CN",
    # halogens and biosignatures
    "HCl", "HF", "CH3Cl", "CH3F", "CH3Br", "SF6",
    # phosphorous
    "PH3", "PS", "PO", "PN"
])

# extend with all gases in the phase database
gases.extend(list(phase.gases.keys()))

# extend with all in cp directory
cp_files = glob.glob(os.path.join(get_gendir(), "compiled", "cp", "*.csv"))
gases.extend([os.path.splitext(os.path.basename(f))[0] for f in cp_files])

# make unique
gases = list(set(gases))
print(gases)
print(len(gases))
# Out:
# ['HCN', 'HOCH2CHO', 'HO2', 'KOH', 'NO', 'CN', 'O2', 'CH4', 'NaO', 'CO2', 'HF', 'CO', 'TiO', 'He', 'C2H6S', 'Na', 'HCO', 'FeO', 'FeH', 'Ar', 'H2SO4', 'H2O', 'Li', 'Kr', 'C3H4', 'SiH2', 'C2N2', 'N2O5', 'HNO3', 'C2H2', 'Na2', 'CH3COCH3', 'SO', 'C', 'SiO', 'Cr', 'HAlO2H', 'H2', 'V', 'S2', 'SO2', 'O3', 'N2O3', 'Mg2', 'N2O4', 'NO2', 'CHOCHO', 'HCl', 'SiH', 'C5', 'CH3', 'CH3ONO2', 'CH3OOH', 'CS2', 'N2H4', 'Ne', 'N2', 'C4H3', 'SiO2', 'PN', 'SO3', 'AlO', 'P', 'Si', 'H2S', 'S', 'SiH4', 'CH3CHO', 'Ca', 'Mg', 'CaO', 'NO3', 'CH3SH', 'TiO2', 'C2H6', 'CH3COCHO', 'O', 'CH3Br', 'C2H5COCH3', 'S3', 'S6', 'CrH', 'C2', 'CH3Cl', 'SF6', 'PH3', 'CH3F', 'OCS', 'C2H4', 'PS', 'MgO', 'Fe', 'C2H3', 'S8', 'C2H6S2', 'Xe', 'H2O2', 'HONO', 'NaOH', 'Al', 'N2O', 'H2CO', 'C3', 'C2H5CHO', 'N', 'PO', 'VO', 'CH3S', 'C4', 'Ti', 'NH3', 'HO2NO2', 'OH', 'K']
# 114

# %%
elem_table = moles.read_elements()

# %%
# Find the name JANAF gives 'gas', based on number of atoms
def find_janaf_name(gas:str):

    target = moles.count_atoms(gas)

    files = glob.glob(os.path.join(get_gendir(),"cp","dat")+"/*.csv")
    for f in files:
        form  = moles.formula_from_path(f)
        atoms = moles.count_atoms(form)

        good = True

        for k in atoms.keys():
            if k not in target.keys():
                good = False
                break

        for k in target.keys():
            if k not in atoms.keys():
                good = False
                break
            if target[k] != atoms[k]:
                good = False
                break

        if good:
            return form

    return ""

# %%
def compile(gas:str):
    print("    compiling %s"%gas)

    # JANAF alias
    janaf = find_janaf_name(gas)
    if len(janaf) == 0:
        print("    skipping (no JANAF data)")
        return
    
    # Git hash
    githash = os.popen("git rev-parse HEAD").read().strip()

    # MMW calculation
    mmw_val = moles.mmw_from_formula(gas, elem_table)

    # create dataset
    ncpath = datdir+"/%s.nc"%gas
    if os.path.exists(ncpath):
        os.remove(ncpath)
    ds = nc.Dataset(ncpath, 'w')

    # JANAF name
    NC_janaf = ds.createVariable('JANAF', str)
    NC_janaf[:] = np.array([janaf], dtype=object)

    # Date created
    NC_today = ds.createVariable('created', 'i8')
    NC_today[:] = today

    # Git hash
    NC_toolshash = ds.createVariable('ThermoTools_GitHash', str)
    NC_toolshash[:] = np.array([githash], dtype=object)

    # MMW
    NC_mmw = ds.createVariable("mmw","f8")
    NC_mmw[:] = mmw_val
    NC_mmw.units = "kg mol-1"

    # Saturation curve
    satdat = os.path.join(get_gendir(),"sat","dat")
    sat_path = satdat+"/%s_sat.csv"%gas
    if os.path.exists(sat_path):
        # Critical point
        T_crit = float(np.loadtxt(satdat+"/%s_crit.csv"%gas))
        NC_tcrit = ds.createVariable("T_crit","f8")
        NC_tcrit[:] = T_crit
        NC_tcrit.units = "K"

        # Triple point
        T_trip = float(np.loadtxt(satdat+"/%s_trip.csv"%gas))
        NC_ttrip = ds.createVariable("T_trip","f8")
        NC_ttrip[:] = T_trip
        NC_ttrip.units = "K"

        # Saturation curve
        X_sat  = np.loadtxt(sat_path, delimiter=',').T
        ds.createDimension("sat",len(X_sat[0]))
        #    temperatures
        NC_tsat = ds.createVariable("sat_T","f8","sat")
        NC_tsat[:] = X_sat[0][:]
        NC_tsat.units = "K"
        #    pressures
        NC_psat = ds.createVariable("sat_P","f8","sat")
        NC_psat[:] = X_sat[1][:]
        NC_psat.units = "log10 Pa"
    else:
        print("    without saturation curve")


    # Latent heat
    lat_path = os.path.join(get_gendir(),"lv","dat")+"/%s.csv"%gas
    if os.path.exists(lat_path):
        X_lat = np.loadtxt(lat_path, delimiter=',').T
        ds.createDimension("lat",len(X_lat[0]))
        #    lookup temperatures
        NC_dHt = ds.createVariable("lat_T","f8","lat")
        NC_dHt[:] = X_lat[0][:]
        NC_dHt.units = "K"
        #    enthalpy changes [J/kg]
        NC_dH = ds.createVariable("lat_H","f8","lat")
        NC_dH[:] = X_lat[1][:]
        NC_dH.units = "J kg-1"
    else:
        print("    without latent heat")


    # Heat capacity
    cap_path = os.path.join(get_gendir(),"cp","dat")+"/%s.csv"%janaf
    X_cap = np.loadtxt(cap_path, delimiter=',').T
    ds.createDimension("cap",len(X_cap[0]))
    #    lookup temperatures
    NC_cpt = ds.createVariable("cap_T","f8","cap")
    NC_cpt[:] = X_cap[0][:]
    NC_cpt.units = "K"
    #   heat capacity
    NC_cp = ds.createVariable("cap_C","f8","cap")
    NC_cp[:] = X_cap[1][:] / mmw_val # convert from "per mol" to "per kg"
    NC_cp.units = "J K-1 kg-1"

    # Van der Waals equation of state (density vs T,P)
    vdw_path = os.path.join(get_gendir(),"vdw","dat")+"/%s.csv"%gas
    if os.path.exists(vdw_path):
        # Load data
        X_vdw = np.loadtxt(vdw_path, delimiter=',').T
        T_vdw = np.unique(X_vdw[0][:])
        P_vdw = np.unique(X_vdw[1][:])

        #    lookup temperatures
        ds.createDimension("vdw_T",len(T_vdw))
        NC_vdwT = ds.createVariable("vdw_T","f8","vdw_T")
        NC_vdwT[:] = T_vdw[:]
        NC_vdwT.units = "K"
        #    lookup pressures [log Pa]
        ds.createDimension("vdw_P",len(P_vdw))
        NC_vdwP = ds.createVariable("vdw_P","f8","vdw_P")
        NC_vdwP[:] = P_vdw[:]
        NC_vdwP.units = "log10 Pa"
        #    density [log kg m-3]
        NC_vdwR = ds.createVariable("vdw_rho","f8",("vdw_P","vdw_T"))
        NC_vdwR[:] = np.reshape(X_vdw[2][:], (len(P_vdw), len(T_vdw)))
        NC_vdwR.units = "log10 kg m-3"
    else:
        print("    without VdW EOS")

    # AQUA equation of state (density vs T,P)
    if gas == "H2O":
        fpath = os.path.join(get_gendir(),"aqua","dat","H2O.csv")
        if os.path.exists(fpath):
            # Load data
            X_eos = np.loadtxt(fpath, delimiter=',').T
            T_eos = np.unique(X_eos[0][:])
            P_eos = np.unique(X_eos[1][:])

            #    lookup temperatures
            ds.createDimension("aqua_T",len(T_eos))
            NC_eosT = ds.createVariable("aqua_T","f8","aqua_T")
            NC_eosT[:] = T_eos[:]
            NC_eosT.units = "K"
            #    lookup pressures [log Pa]
            ds.createDimension("aqua_P",len(P_eos))
            NC_eosP = ds.createVariable("aqua_P","f8","aqua_P")
            NC_eosP[:] = P_eos[:]
            NC_eosP.units = "log10 Pa"
            #    density [log kg m-3]
            NC_eosR = ds.createVariable("aqua_rho","f8",("aqua_P","aqua_T"))
            NC_eosR[:] = np.reshape(X_eos[2][:], (len(P_eos), len(T_eos)))
            NC_eosR.units = "log10 kg m-3"
        else:
            print("    without AQUA EOS")

    # CMS19 equation of state (density vs T,P)
    if gas == "H2":
        fpath = os.path.join(get_gendir(),"cms19","dat","H2.csv")
        if os.path.exists(fpath):
            # Load data
            X_eos = np.loadtxt(fpath, delimiter=',').T
            T_eos = np.unique(X_eos[0][:])
            P_eos = np.unique(X_eos[1][:])

            #    lookup temperatures
            ds.createDimension("cms19_T",len(T_eos))
            NC_eosT = ds.createVariable("cms19_T","f8","cms19_T")
            NC_eosT[:] = T_eos[:]
            NC_eosT.units = "K"
            #    lookup pressures [log Pa]
            ds.createDimension("cms19_P",len(P_eos))
            NC_eosP = ds.createVariable("cms19_P","f8","cms19_P")
            NC_eosP[:] = P_eos[:]
            NC_eosP.units = "log10 Pa"
            #    density [log kg m-3]
            NC_eosR = ds.createVariable("cms19_rho","f8",("cms19_P","cms19_T"))
            NC_eosR[:] = np.reshape(X_eos[2][:], (len(P_eos), len(T_eos)))
            NC_eosR.units = "log10 kg m-3"
        else:
            print("    without CMS19 EOS")

    # done with netcdf
    ds.close()

    # create checksum file
    writesum(ncpath)

# %%
print("Compiling individual data files...")
for ig,g in enumerate(gases):
    print(f"Gas {g} ({ig+1}/{len(gases)})")
    compile(g)

print(" ")
files = glob.glob(datdir+"/*.nc*")
files = [os.path.abspath(f) for f in files]
zpath = os.path.join(datdir, "gases.zip")
makezip(zpath, files)
# Out:
# Compiling individual data files...
# Gas HCN (1/114)
#     compiling HCN
#     checksum: /home/harrison/Projects/ThermoTools/generated/compiled/dat/HCN.nc.chk
# Gas HOCH2CHO (2/114)
#     compiling HOCH2CHO
#     skipping (no JANAF data)
# Gas HO2 (3/114)
#     compiling HO2
#     without saturation curve
#     without latent heat
#     without VdW EOS
#     checksum: /home/harrison/Projects/ThermoTools/generated/compiled/dat/HO2.nc.chk
# Gas KOH (4/114)
#     compiling KOH
#     without saturation curve
#     without latent heat
#     without VdW EOS
#     checksum: /home/harrison/Projects/ThermoTools/generated/compiled/dat/KOH.nc.chk
# Gas NO (5/114)
#     compiling NO
#     without saturation curve
#     without latent heat
#     checksum: /home/harrison/Projects/ThermoTools/generated/compiled/dat/NO.nc.chk
# Gas CN (6/114)
#     compiling CN
#     without saturation curve
#     without latent heat
#     without VdW EOS
# ...

# %%
def no_data_text(ax):
    ax.text(0.5, 0.5, "NO DATA", transform=ax.transAxes, horizontalalignment='center', verticalalignment='center', color='tab:red')

# %%
# Make plots
print("Making plots from NetCDF files...")

files = glob.glob(datdir+"/*.nc")
print("Found %d files"%len(files))

for f in files:

    gas = moles.formula_from_path(f)
    print("    "+gas)

    ds = nc.Dataset(f,'r')

    fig,axs = plt.subplots(4,1, sharex=True, figsize=(9,8))

    axs[0].set_title(gas)

    axs[0].set_ylabel(r"P$_{\text{sat}}$" +"\n[bar]")
    if "sat_T" in ds.variables.keys():
        axs[0].plot(ds.variables["sat_T"][:],  10**ds.variables["sat_P"][:]*1e-5)
        axs[0].set_yscale("symlog", linthresh=1e-4)
    else:
        no_data_text(axs[0])

    axs[1].set_ylabel(r"$\Delta$H"+"\n"+r"[kJ kg$^{-1}$]")
    if "lat_T" in ds.variables.keys():
        axs[1].plot(ds.variables["lat_T"][:],    ds.variables["lat_H"][:]*1e-3)
    else:
        no_data_text(axs[1])

    axs[2].set_ylabel(r"$C_p$" + "\n" + r"[kJ K$^{-1}$ kg$^{-1}$]")
    if "cap_T" in ds.variables.keys():
        axs[2].plot(ds.variables["cap_T"][:],    ds.variables["cap_C"][:]*1e-3)
    else:
        no_data_text(axs[2])

    has_eos = False
    axs[3].set_ylabel("Gas density @ 1 bar \n" + r"[kg m$^{-3}$]")
    if "vdw_T" in ds.variables.keys():
        arr_t = ds.variables["vdw_T"][:]
        arr_p = ds.variables["vdw_P"][:]
        arr_r = ds.variables["vdw_rho"][:]
        iclose = np.argmin(np.abs(arr_p - 5))
        axs[3].plot(arr_t,10**arr_r[iclose,:], label="Van der Waals")
        has_eos = True
    if "aqua_T" in ds.variables.keys():
        arr_t = ds.variables["aqua_T"][:]
        arr_p = ds.variables["aqua_P"][:]
        arr_r = ds.variables["aqua_rho"][:]
        iclose = np.argmin(np.abs(arr_p - 5))
        axs[3].plot(arr_t,10**arr_r[iclose,:], label="AQUA", ls='dashed')
        has_eos = True
    if has_eos:
        axs[3].legend()
        axs[3].set_yscale("log")
    else:
        no_data_text(axs[3])


    axs[-1].set_xlabel("Temperature [K]")
    fig.savefig(pltdir + "/%s.png"%gas, bbox_inches='tight', dpi=220)
    plt.close("all")

    ds.close()
print("Done!")
# Out:
# Making plots from NetCDF files...
# Found 88 files
#     HCN
#     HO2
#     KOH
#     NO
#     CN
#     O2
#     CH4
#     NaO
#     CO2
#     CO
#     TiO
#     He
#     Na
#     HCO
#     FeO
#     Ar
#     H2SO4
#     H2O
#     Kr
#     C2N2
#     N2O5
#     HNO3
#     C2H2
#     Na2
#     SO
#     C
#     SiO
#     H2
#     V
#     S2
#     SO2
#     O3
#     N2O3
#     Mg2
#     N2O4
#     NO2
#     HCl
#     SiH
#     C5
#     CH3
#     CS2
#     N2H4
#     Ne
#     N2
#     SiO2
#     PN
#     SO3
#     AlO
#     P
#     Si
#     H2S
#     S
#     SiH4
#     CH3CHO
#     Ca
#     Mg
#     CaO
#     NO3
#     TiO2
#     O
#     S3
#     S6
#     C2
#     CH3Cl
#     PH3
#     CH3F
#     OCS
#     C2H4
#     PS
#     MgO
#     Fe
#     S8
#     Xe
#     H2O2
#     HONO
#     NaOH
#     Al
#     N2O
#     H2CO
#     C3
#     N
#     PO
#     VO
#     C4
#     Ti
#     NH3
#     OH
#     K
# Done!
